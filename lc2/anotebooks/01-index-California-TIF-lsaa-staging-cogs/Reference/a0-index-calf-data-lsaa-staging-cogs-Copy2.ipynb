# %% [markdown]
# # index and test calf data
# ## lsaa-staging-cog

# %%
! aws s3 ls |grep lsaa
# Out:
# 2019-02-07 22:16:43 lsaa-cog-test
# 2019-02-07 22:17:09 lsaa-incoming
# 2019-02-07 22:17:40 lsaa-level1-data
# 2019-02-07 22:18:16 lsaa-staging-cog
# 2019-02-07 22:54:37 lsaa-staging-logs
# 2019-02-07 22:54:09 lsaa-staging-stac
# 2019-02-07 22:53:28 lsaa-staging-tar
# 2019-02-07 22:52:58 lsaa-staging-thumbnail
# 2019-02-07 22:51:58 lsaa-test-cog
# 2019-02-07 22:51:27 lsaa-test-tar

# %%
! aws s3 ls lsaa-staging-cog
# Out:
#                            PRE L04/
#                            PRE L05/
#                            PRE L07/
#                            PRE L08/

# %% [markdown]
# # Get the AOI using geojson.io
#
#
# http://geojson.io/#map=10/30.2/-2.2

# %%
#!scp sleepy:./Downloads/\*.geojson .
#! mv "map(3).geojson" lake_rumira.geojson

# %%
#! rm map*

# %%
# !ls lake*
# Out:
# lake_rumira.geojson

# %%
import datetime
from lilcubeLib.lc_api import Lilcube

my_aoi_file = 'lake_rumira.geojson'

date_range = (datetime.datetime(2013,2,1), datetime.datetime(2015,7,31))
# date_range = (datetime(2013,7,6), datetime(2018,7,7))

es_index = 'datacube'
es_type = 'rwanda'

lc = Lilcube()

measurements = ('red','green','blue',)

# return a pandas data frame product id creation date and red
panda_df = lc.search(es_index, es_type, my_aoi_file, 
             time = date_range, measurements = measurements )
# Out:
# creating Lilcube class
# Your Index is: datacube
# Your Record Type for this index is: rwanda
# MYBODY: <class 'str'>
# {"query": {"bool": {"must": [{"range": {"creation_dt": {"gte": "2013-02-01"}}}, {"range": {"creation_dt": {"lt": "2015-07-31"}}}], "filter": [{"geo_shape": {"footprint": {"shape": {"type": "Polygon", "coordinates": [[[30.211029052734375, -2.220055849443337], [30.25154113769531, -2.220055849443337], [30.25154113769531, -2.1576167016312597], [30.211029052734375, -2.1576167016312597], [30.211029052734375, -2.220055849443337]]]}}}}]}}}
# Yay Connect

# %%
panda_df
# Out:
# Empty DataFrame
# Columns: [product, band, path, row, date, red, green, blue, nir, pixel_qa]
# Index: []

# %%
#!scp sleepy:./Downloads/\*.geojson .
#! mv "map(4).geojson" pine_lake.geojson
#! rm map*

# %%
! ls
# Out:
# a0-index-calf-data-lsaa-staging-cogs.ipynb  lake_rumira.geojson
# fake_path_row.geojson			    pine_lake.geojson

# %%
import datetime
from lilcubeLib.lc_api import Lilcube

my_aoi_file = 'pine_lake.geojson'

date_range = (datetime.datetime(2013,2,1), datetime.datetime(2015,7,31))
# date_range = (datetime(2013,7,6), datetime(2018,7,7))

es_index = 'datacube'
es_type = 'rwanda'

lc = Lilcube()

measurements = ('red','green','blue',)

# return a pandas data frame product id creation date and red
panda_df = lc.search(es_index, es_type, my_aoi_file, 
             time = date_range, measurements = measurements )
# Out:
# creating Lilcube class
# Your Index is: datacube
# Your Record Type for this index is: rwanda
# MYBODY: <class 'str'>
# {"query": {"bool": {"must": [{"range": {"creation_dt": {"gte": "2013-02-01"}}}, {"range": {"creation_dt": {"lt": "2015-07-31"}}}], "filter": [{"geo_shape": {"footprint": {"shape": {"type": "Polygon", "coordinates": [[[-119.35272216796874, 36.81808022778526], [-119.2510986328125, 36.81808022778526], [-119.2510986328125, 36.91915611148194], [-119.35272216796874, 36.91915611148194], [-119.35272216796874, 36.81808022778526]]]}}}}]}}}
# Yay Connect

# %%
panda_df
# Out:
# Empty DataFrame
# Columns: [product, band, path, row, date, red, green, blue, nir, pixel_qa]
# Index: []

# %% [markdown]
# # major bummer - does not find any records - what can we do about it
# 1. be patient
# 2. start a cube calif es_index and es_type NOW!
#
# but HOW?
# 1. v2_index - find it

# %%
import datetime
from lilcubeLib.lc_api import Lilcube

my_aoi_file = 'pine_lake.geojson'

date_range = (datetime.datetime(2013,2,1), datetime.datetime(2015,7,31))
# date_range = (datetime(2013,7,6), datetime(2018,7,7))

es_index = 'cube'
es_type = 'calif'

lc = Lilcube()

measurements = ('red','green','blue',)

# return a pandas data frame product id creation date and red
panda_df = lc.search(es_index, es_type, my_aoi_file, 
             time = date_range, measurements = measurements )
# Out:
# creating Lilcube class
# Your Index is: cube
# Your Record Type for this index is: calif
# MYBODY: <class 'str'>
# {"query": {"bool": {"must": [{"range": {"creation_dt": {"gte": "2013-02-01"}}}, {"range": {"creation_dt": {"lt": "2015-07-31"}}}], "filter": [{"geo_shape": {"footprint": {"shape": {"type": "Polygon", "coordinates": [[[-119.35272216796874, 36.81808022778526], [-119.2510986328125, 36.81808022778526], [-119.2510986328125, 36.91915611148194], [-119.35272216796874, 36.91915611148194], [-119.35272216796874, 36.81808022778526]]]}}}}]}}}
# Yay Connect

# %%
panda_df
# Out:
#       product       band path row        date  \
# 0   LC08_L2SP  band4.TIF  042  34  2014-01-15
# 1   LC08_L2SP  band4.TIF  042  34  2014-01-31
# 2   LC08_L2SP  band4.TIF  042  34  2014-02-16
# 3   LC08_L2SP  band4.TIF  042  34  2014-03-04
# 4   LC08_L2SP  band4.TIF  042  34  2014-03-20
# 5   LC08_L2SP  band4.TIF  042  34  2014-04-05
# 6   LC08_L2SP  band4.TIF  042  34  2014-04-21
# 7   LC08_L2SP  band4.TIF  042  34  2014-05-07
# 8   LC08_L2SP  band4.TIF  042  34  2014-05-23
# 9   LC08_L2SP  band4.TIF  042  34  2014-06-08
# 10  LC08_L2SP  band4.TIF  042  34  2014-06-24
# 11  LC08_L2SP  band4.TIF  042  34  2014-07-10
# 12  LC08_L2SP  band4.TIF  042  34  2014-07-26
# 13  LC08_L2SP  band4.TIF  042  34  2014-08-11
# 14  LC08_L2SP  band4.TIF  042  34  2014-08-27
# 15  LC08_L2SP  band4.TIF  042  34  2014-09-12
# 16  LC08_L2SP  band4.TIF  042  34  2014-09-28
# 17  LC08_L2SP  band4.TIF  042  34  2014-10-14
# 18  LC08_L2SP  band4.TIF  042  34  2014-10-30
# 19  LC08_L2SP  band4.TIF  042  34  2014-11-15
# 20  LC08_L2SP  band4.TIF  042  34  2014-12-01
# 21  LC08_L2SP  band4.TIF  042  34  2014-12-17
#
#                                                   red  \
# 0   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
#
#                                                 green  \
# 0   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
#
#                                                  blue  \
# 0   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
#
#                                                   nir  \
# 0   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
#
#                                              pixel_qa
# 0   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/042/034/LC08_L2...

# %% [markdown]
# # That's Cool What's NEXT Tony?
#
# 0. test load and organize the index main into bin
# 1. index all of L8 - california
# 2. play with tighter date ranges -
# 3. make lc.load return build_array
# 4. expand to ther clouds
# 5. composites and videos

# %%
def _aload(aoi_geojson_file_name, measurements, panda_df):
    print(aoi_geojson_file_name)

# %%
print (my_aoi_file)
print (measurements)
_aload(my_aoi_file, measurements, panda_df)

ds = lc.load(my_aoi_file, measurements, panda_df)
# Out:
# pine_lake.geojson
# ('red', 'green', 'blue')
# pine_lake.geojson
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c1dba64549c4> in <module>
#       3 _aload(my_aoi_file, measurements, panda_df)
#       4
# ----> 5 ds = lc.load(my_aoi_file, measurements, panda_df)
#
# /opt/little-cloud/lib/lilcubeLib/lilcubeLib/lc_api.py in load(self, aoi_geojson_file_name, measurements, panda_df)
#      31
#      32     def load(self, aoi_geojson_file_name, measurements, panda_df):
# ---> 33         bbox = bounding_box_tuple_from_geojson(aoi_geojson_file_name)
#      34         aoi = AOI_bounding_box(bbox)
#      35         THE_XARRAY = build_the_xarray(aoi.geobox, measurements, panda_df)
#
# NameError: name 'bounding_box_tuple_from_geojson' is not defined

# %%
'''

def load(aoi_geojson_file_name, measurements, panda_df):
        bbox = bounding_box_tuple_from_geojson(aoi_geojson_file_name)
        aoi = AOI_bounding_box(bbox)
        THE_XARRAY = build_the_xarray(aoi.geobox, measurements, panda_df)
        return (THE_XARRAY)
'''
