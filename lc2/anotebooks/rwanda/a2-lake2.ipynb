# %% [markdown]
# # Example notebook

# %%
import datacube
dc= datacube.Datacube()

# %%
! datacube  product list
# Out:
# description: Landsat 8 ESPA ARD Local Disk Product Definition - Tonu Butzer elastic
# format: GeoTiff
# id: 16
# instrument: OLI_TIRS
# lat: null
# lon: null
# name: l8_rwanda
# platform: LANDSAT_8
# product_type: espa
# time: null

# %%
from datetime import datetime
date_range = (
        datetime(2012,5,20),
        datetime(2014,6,30))

# %%
# from bounding box
# https://boundingbox.klokantech.com/
# extent = (30.209661,-2.218817,30.246396,-2.163926)
# extent = (31.6575,-3.0849,32.1189,-2.4539)
# extent = (31.6629,-2.834,31.7156,-2.7146)
extent = (30.3537,-2.4337,30.4608,-2.3239)

x = (extent[0],extent[2])
y = (extent[1],extent[3])

print (x,y)

aoix = x
aoiy = y
# Out:
# (30.3537, 30.4608) (-2.4337, -2.3239)

# %%
product = 'l8_rwanda'
ds = dc.load(product=product,x = x, y = y,
             output_crs = 'epsg:32636', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )
# Out:
# TONY product= l8_rwanda

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 68, x: 399, y: 407)
# Coordinates:
#   * time     (time) datetime64[ns] 2013-04-10T08:07:38.966632 ... 2014-06-23T08:08:01.094953
#   * y        (y) float64 -2.571e+05 -2.571e+05 ... -2.693e+05 -2.693e+05
#   * x        (x) float64 2.057e+05 2.057e+05 2.057e+05 ... 2.176e+05 2.176e+05
# Data variables:
#     red      (time, y, x) int16 -9999 -9999 -9999 -9999 ... 632 616 611 529
#     green    (time, y, x) int16 -9999 -9999 -9999 -9999 ... 602 578 583 555
#     blue     (time, y, x) int16 -9999 -9999 -9999 -9999 ... 377 384 358 319
#     nir      (time, y, x) int16 -9999 -9999 -9999 -9999 ... 2337 2210 2300 2520
# Attributes:
#     crs:      epsg:32636

# %%
from noteLib import *
# %matplotlib inline
for t in range(0,22):
    cnt=t
    figsize=[8,8]
    plot_labeled_rgb(ds, t, cnt, figsize=figsize)
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
m = display_map(y,x)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print (aoix)
print(aoiy)
# Out:
# (30.3537, 30.4608)
# (-2.4337, -2.3239)
