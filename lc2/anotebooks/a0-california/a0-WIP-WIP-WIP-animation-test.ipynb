# %% [markdown]
# # Visualizations - requirements by demo and analog
#
# ### DEA Plotting Testing - January 25, 2019
#
#
# # Concept
#
# ## 0. Define a science visualization problem (SCIENCE)
#
# ## 1. Choose a data store or data lake (STORAGE)
#
# ## 2. Choose a compute platform (COMPUTE)
#
# ## 3. Load SOFTWARE: Tony's little-cloud/odc-lite - modeled after the ODC and PANGEO reference architecture
#
# ## 4. Visualize your time series data
#
#
# > Hey You Get Off My Cloud

# %% [markdown]
# # Refine the Visualization Dataset
#
# 1. select an AOI Area of Interest
# 2. Filter by criteria
# 3. Extract only the "pretty scenes" - manually or by machine learning
#     - prune, select, repeat
# 4. visualize, visualize, visualize
#     - rasters, vectors, overlays, indexes - NDVI, NDWI -
#     - heatmaps
#     - pixel quality
#     - pyccd and wofs models
#     - raster products
#     - side by side
#     - juxtapose
#     - ANIMATIONS

# %% [markdown]
# ### Locate the area of interest using bounding box

# %% [markdown]
# # dragon lake fresno
# ## Pine Flat Lake
#
# https://boundingbox.klokantech.com/
# -119.36417,36.810925,-119.218601,36.93287

# %% [markdown]
# ![lake](http://www.californiasgreatestlakes.com/photos3/pine_flat_lake.jpg)

# %%
from noteLib import *


ulx=-2257500.000000
uly=2012700.000000

lrx=-1998000.000000
lry=1747200.000000

m = aea_base_map(ulx,uly,lrx,lry)
aea_display_map(m,ulx,uly, lrx,lry)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Image(filename=('assets/rwanda_map.png'))

# %% [markdown]
# # ![pangeo](https://pangeo.io/_images/pangeo_tech_1.png)

# %% [markdown]
# # ![odc overview](https://cdn-images-1.medium.com/max/1200/1*2XgL8GGYEvDcOpiqZaWJ7Q.png)

# %%
# Image(filename=('assets/rumira_aoi.png'))

# %%
from notebookLib.nb_DEAPlotting import nb_rgb

# %%
import datetime
#import numpy
#import xarray
#import rasterio
from lilcubeLib.lc_api import Lilcube
#from noteLib import ge_translate

# %%
from lilcubeLib.lc_xarray import AOI_bounding_box, Xpart
from lilcubeLib.lc_xarray import build_the_xarray

# %%
aoi = AOI_bounding_box((-119.36417,36.810925,-119.218601,36.93287)) #bounding box for pine flat lake, Fresno, Ca
# -119.36417,36.810925,-119.218601,36.93287

# %%
date_range = (datetime.datetime(2013,2,1), datetime.datetime(2015,7,31))
# date_range = (datetime(2013,7,6), datetime(2018,7,7))

es_index = 'datacube'
es_type = 'rwanda'

lc = Lilcube()

measurements = ('red','green','blue',)

# return a pandas data frame product id creation date and red
panda_df = lc.search(es_index, es_type, (aoi.ul_lat, aoi.ul_lon), (aoi.lr_lat, aoi.lr_lon),
             time = date_range, measurements = measurements )
# Out:
# creating Lilcube class
# Yay Connect

# %%
panda_df
# Out:
#       product       band path row        date  \
# 0   LC08_L2SP  band4.TIF  043  35  2013-08-15
# 1   LC08_L2SP  band4.TIF  043  35  2013-08-31
# 2   LC08_L2SP  band4.TIF  043  35  2013-09-16
# 3   LC08_L2SP  band4.TIF  043  35  2013-10-02
# 4   LC08_L2SP  band4.TIF  043  35  2013-10-18
# 5   LC08_L2SP  band4.TIF  043  35  2013-11-03
# 6   LC08_L2SP  band4.TIF  043  35  2013-11-19
# 7   LC08_L2SP  band4.TIF  043  35  2013-12-05
# 8   LC08_L2SP  band4.TIF  043  35  2013-04-25
# 9   LC08_L2SP  band4.TIF  043  35  2013-05-11
# 10  LC08_L2SP  band4.TIF  043  35  2013-05-27
# 11  LC08_L2SP  band4.TIF  043  35  2013-06-12
# 12  LC08_L2SP  band4.TIF  043  35  2013-12-21
# 13  LC08_L2SP  band4.TIF  043  35  2014-10-21
# 14  LC08_L2SP  band4.TIF  043  35  2014-11-06
# 15  LC08_L2SP  band4.TIF  043  35  2014-03-11
# 16  LC08_L2SP  band4.TIF  043  35  2014-03-27
# 17  LC08_L2SP  band4.TIF  043  35  2014-04-12
# 18  LC08_L2SP  band4.TIF  043  35  2014-04-28
# 19  LC08_L2SP  band4.TIF  043  35  2014-05-14
# 20  LC08_L2SP  band4.TIF  043  35  2014-12-24
# 21  LC08_L2SP  band4.TIF  043  35  2014-01-06
# 22  LC08_L2SP  band4.TIF  043  35  2014-01-22
# 23  LC08_L2SP  band4.TIF  043  35  2014-02-07
# 24  LC08_L2SP  band4.TIF  043  35  2014-02-23
# 25  LC08_L2SP  band4.TIF  043  35  2015-01-09
# 26  LC08_L2SP  band4.TIF  043  35  2015-01-25
# 27  LC08_L2SP  band4.TIF  043  35  2015-02-26
# 28  LC08_L2SP  band4.TIF  043  35  2015-03-14
# 29  LC08_L2SP  band4.TIF  043  35  2015-03-30
# 30  LC08_L2SP  band4.TIF  043  35  2015-04-15
# 31  LC08_L2SP  band4.TIF  043  35  2015-05-01
#
#                                                   red  \
# 0   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 22  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 23  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 24  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 25  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 26  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 27  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 28  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 29  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 30  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 31  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
#
#                                                 green  \
# 0   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 22  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 23  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 24  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 25  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 26  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 27  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 28  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 29  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 30  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 31  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
#
#                                                  blue  \
# 0   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 22  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 23  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 24  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 25  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 26  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 27  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 28  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 29  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 30  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 31  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
#
#                                                   nir  \
# 0   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 22  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 23  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 24  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 25  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 26  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 27  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 28  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 29  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 30  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 31  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
#
#                                              pixel_qa
# 0   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 1   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 2   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 3   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 4   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 5   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 6   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 7   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 8   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 9   s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 10  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 11  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 12  s3://lsaa-staging-cog/L08/2013/043/035/LC08_L2...
# 13  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 14  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 15  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 16  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 17  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 18  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 19  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 20  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 21  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 22  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 23  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 24  s3://lsaa-staging-cog/L08/2014/043/035/LC08_L2...
# 25  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 26  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 27  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 28  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 29  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 30  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...
# 31  s3://lsaa-staging-cog/L08/2015/043/035/LC08_L2...

# %%
len(panda_df)
# Out:
# 32

# %%
# df2 = panda_df.loc[panda_df['path']=='172']

### FIX for rwanda not needed here

#df.loc[df['column_name'] == some_value]

#df2

# %%
df2 = panda_df

# %%
red = df2.iloc[2]['red']
red
# Out:
# 's3://lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130916_20171310_01_A1/LC08_L2SP_043035_20130916_20171310_01_A1_sr_band4.TIF'

# %%
# !aws s3 ls 's3://lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130815_20171310_01_A1/LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF'
# Out:
# 2018-08-14 21:28:34   76826843 LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF
# 2018-08-14 21:28:34   15372891 LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF.ovr

# %%
red_vsi = red.replace("s3:/","/vsis3")
red_vsi
# Out:
# '/vsis3/lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130916_20171310_01_A1/LC08_L2SP_043035_20130916_20171310_01_A1_sr_band4.TIF'

# %%
# !gdalinfo '/vsis3/lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130815_20171310_01_A1/LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF'
# Out:
# Driver: GTiff/GeoTIFF
# Files: /vsis3/lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130815_20171310_01_A1/LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF
#        /vsis3/lsaa-staging-cog/L08/2013/043/035/LC08_L2SP_043035_20130815_20171310_01_A1/LC08_L2SP_043035_20130815_20171310_01_A1_sr_band4.TIF.ovr
# Size is 8661, 8841
# Coordinate System is:
# PROJCS["Albers",
#     GEOGCS["WGS 84",
#         DATUM["WGS_1984",
#             SPHEROID["WGS 84",6378140,298.2569999999957,
#                 AUTHORITY["EPSG","7030"]],
#             AUTHORITY["EPSG","6326"]],
#         PRIMEM["Greenwich",0],
#         UNIT["degree",0.0174532925199433],
#         AUTHORITY["EPSG","4326"]],
#     PROJECTION["Albers_Conic_Equal_Area"],
#     PARAMETER["standard_parallel_1",29.5],
#     PARAMETER["standard_parallel_2",45.5],
#     PARAMETER["latitude_of_center",23],
#     PARAMETER["longitude_of_center",-96],
#     PARAMETER["false_easting",0],
#     PARAMETER["false_northing",0],
#     UNIT["metre",1,
#         AUTHORITY["EPSG","9001"]]]
# Origin = (-2335815.000000000000000,1867515.000000000000000)
# Pixel Size = (30.000000000000000,-30.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
#   Band_1=band 4 surface reflectance
# Image Structure Metadata:
#   COMPRESSION=DEFLATE
#   INTERLEAVE=BAND
# Corner Coordinates:
# Upper Left  (-2335815.000, 1867515.000) (122d48' 7.58"W, 36d52' 3.66"N)
# Lower Left  (-2335815.000, 1602285.000) (121d59'27.41"W, 34d35'21.64"N)
# Upper Right (-2075985.000, 1867515.000) (119d57' 9.37"W, 37d28'46.58"N)
# Lower Right (-2075985.000, 1602285.000) (119d13'12.38"W, 35d11' 2.60"N)
# Center      (-2205900.000, 1734900.000) (120d59'28.36"W, 36d 2'22.50"N)
# Band 1 Block=512x512 Type=Int16, ColorInterp=Gray
#   Description = band 4 surface reflectance
#   NoData Value=-9999
#   Overviews: 4331x4421

# %%
import rasterio
redfile = red
with rasterio.open(redfile) as src:
    w = src.read(1)

print(w.shape)
# Out:
# (8851, 8661)

# %%
redfile = red_vsi
with rasterio.open(redfile) as src:
    w = src.read(1)

print(w.shape)
# Out:
# (8851, 8661)

# %%
import matplotlib.pyplot as plt

img_toshow = exposure.equalize_hist(w, mask = np.isfinite(w))

fig1 = plt.figure(figsize=(10,10))
imgplot = plt.imshow(img_toshow)

# %% [markdown]
# ## ds = build_the_xarray(aoi.geobox, measurements, df2)

# %%
# %%time
#ds = build_the_xarray(aoi.geobox, measurements, panda_df)
ds = build_the_xarray(aoi.geobox, measurements, df2)
# Out:
# TON letime_coords 32
# INDEX= 0 red
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/little-cloud/lib/lilcubeLib/lilcubeLib/lc_xarray.py in build_the_xarray(geobox, measures, df)
#     183         for index in range(0,len(time_coords)):
#     184             print("INDEX=",index,color)
# --> 185             read_data_from_geotiff(data[color][index], index, color, geobox, df)
#     186
#     187         # print(THE_XARRAY)
#
# /opt/little-cloud/lib/lilcubeLib/lilcubeLib/lc_xarray.py in read_data_from_geotiff(databuf, index, color, geobox, df)
#     127     # print(rows[0], rows[1])
#     128     holding_tank = my_raster[rows[0]:rows[1], cols[0]:cols[1]]
# --> 129     numpy.copyto(databuf,holding_tank)
#     130
#     131
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/common.py in __array__(self, dtype)
#     100
#     101     def __array__(self, dtype=None):
# --> 102         return np.asarray(self.values, dtype=dtype)
#     103
#     104     def __repr__(self):
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/dataarray.py in values(self)
#     404     def values(self):
#     405         """The array's data as a numpy.ndarray"""
# --> 406         return self.variable.values
#     407
#     408     @values.setter
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/variable.py in values(self)
#     382     def values(self):
#     383         """The variable's data as a numpy.ndarray"""
# --> 384         return _as_array_or_item(self._data)
#     385
#     386     @values.setter
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/variable.py in _as_array_or_item(data)
#     206     TODO: remove this (replace with np.asarray) once these issues are fixed
#     207     """
# --> 208     data = np.asarray(data)
#     209     if data.ndim == 0:
#     210         if data.dtype.kind == 'M':
#
# ~/.local/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# /usr/local/lib/python3.6/dist-packages/dask/array/core.py in __array__(self, dtype, **kwargs)
#    1116
#    1117     def __array__(self, dtype=None, **kwargs):
# -> 1118         x = self.compute()
#    1119         if dtype and x.dtype != dtype:
#    1120             x = x.astype(dtype)
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# /usr/local/lib/python3.6/dist-packages/dask/base.py in compute(*args, **kwargs)
#     395     keys = [x.__dask_keys__() for x in collections]
#     396     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 397     results = schedule(dsk, keys, **kwargs)
#     398     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     399
#
# /usr/local/lib/python3.6/dist-packages/dask/threaded.py in get(dsk, result, cache, num_workers, **kwargs)
#      74     results = get_async(pool.apply_async, len(pool._pool), dsk, result,
#      75                         cache=cache, get_id=_thread_get_id,
# ---> 76                         pack_exception=pack_exception, **kwargs)
#      77
#      78     # Cleanup pools associated to dead threads
#
# /usr/local/lib/python3.6/dist-packages/dask/local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     499                         _execute_task(task, data)  # Re-execute locally
#     500                     else:
# --> 501                         raise_exception(exc, tb)
#     502                 res, worker_id = loads(res_info)
#     503                 state['cache'][key] = res
#
# /usr/local/lib/python3.6/dist-packages/dask/compatibility.py in reraise(exc, tb)
#     110         if exc.__traceback__ is not tb:
#     111             raise exc.with_traceback(tb)
# --> 112         raise exc
#     113
#     114 else:
#
# /usr/local/lib/python3.6/dist-packages/dask/local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     270     try:
#     271         task, data = loads(task_info)
# --> 272         result = _execute_task(task, data)
#     273         id = get_id()
#     274         result = dumps((result, id))
#
# /usr/local/lib/python3.6/dist-packages/dask/local.py in _execute_task(arg, cache, dsk)
#     251         func, args = arg[0], arg[1:]
#     252         args2 = [_execute_task(a, cache) for a in args]
# --> 253         return func(*args2)
#     254     elif not ishashable(arg):
#     255         return arg
#
# /usr/local/lib/python3.6/dist-packages/dask/array/core.py in getter(a, b, asarray, lock)
#     112         c = a[b]
#     113         if asarray:
# --> 114             c = np.asarray(c)
#     115     finally:
#     116         if lock:
#
# ~/.local/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/indexing.py in __array__(self, dtype)
#     600
#     601     def __array__(self, dtype=None):
# --> 602         return np.asarray(self.array, dtype=dtype)
#     603
#     604     def __getitem__(self, key):
#
# ~/.local/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/indexing.py in __array__(self, dtype)
#     506     def __array__(self, dtype=None):
#     507         array = as_indexable(self.array)
# --> 508         return np.asarray(array[self.key], dtype=None)
#     509
#     510     def transpose(self, order):
#
# /usr/local/lib/python3.6/dist-packages/xarray/backends/rasterio_.py in __getitem__(self, key)
#     121     def __getitem__(self, key):
#     122         return indexing.explicit_indexing_adapter(
# --> 123             key, self.shape, indexing.IndexingSupport.OUTER, self._getitem)
#     124
#     125
#
# /usr/local/lib/python3.6/dist-packages/xarray/core/indexing.py in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#     774     """
#     775     raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# --> 776     result = raw_indexing_method(raw_key.tuple)
#     777     if numpy_indices.tuple:
#     778         # index the loaded np.ndarray
#
# /usr/local/lib/python3.6/dist-packages/xarray/backends/rasterio_.py in _getitem(self, key)
#     108         if not band_key or any(start == stop for (start, stop) in window):
#     109             # no need to do IO
# --> 110             shape = (len(band_key),) + tuple(
#     111                 stop - start for (start, stop) in window)
#     112             out = np.zeros(shape, dtype=self.dtype)
#
# TypeError: object of type 'int' has no len()

# %%
ds
ds2 = ds
#ds2 = ds.sel(datePR=slice('2013-07-06_172_61', '2013-07-06_172_62'))

#ds.sel(datePR=slice('2013-07-06_172_61', '2013-07-06_172_62')).plot.imshow('x', 'y', col='time', col_wrap=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-832d410de6ce> in <module>
# ----> 1 ds
#       2 ds2 = ds
#       3 #ds2 = ds.sel(datePR=slice('2013-07-06_172_61', '2013-07-06_172_62'))
#       4
#       5 #ds.sel(datePR=slice('2013-07-06_172_61', '2013-07-06_172_62')).plot.imshow('x', 'y', col='time', col_wrap=4)
#
# NameError: name 'ds' is not defined

# %%
ds2

# %%
# dir(ds2)

# %%
display_color='red'
# ds2[display_color].plot.imshow('x', 'y', col='datePR', col_wrap=4, cmap='tab20')

# %% [markdown]
# https://matplotlib.org/examples/color/colormaps_reference.html

# %%
# !date

# %%
display_color='red'
# ds2[display_color].plot.imshow('x', 'y', col='datePR', col_wrap=4, cmap='flag')
ds2[display_color].plot.imshow('x', 'y', col='datePR', col_wrap=4, cmap='prism')

# %%
# help(nb_rgb)

# %%
nb_rgb(ds2,bands = ['red', 'green', 'blue'], index = [0,1,6,7,8,11,13,14,15,16,20,21], index_dim='datePR',  
       percentile_stretch=(.2,.85), aspect=1.2)

# %%
nb_rgb(ds2,bands = ['red', 'green', 'blue'], index = [0,1,6,7,8,11,13,14,15,16,20,21], index_dim='datePR',  
       percentile_stretch=(.5,.85), aspect=1.2)

# %%
nb_rgb(ds2,bands = ['red', 'green', 'blue'], index = [0,1,6,7,8,11,13,14,15,16,20,21], index_dim='datePR',  
       percentile_stretch=(.2,.85), aspect=.7)

# %%
nb_rgb(ds2,bands = ['red', 'green', 'blue'], index = 0, index_dim='datePR')

# %%
# from noteLib import *
# %matplotlib inline
for t in range(0,len(ds2.datePR)):
    cnt=t
    figsize=[6,6]
    #plot_labeled_rgb(ds2, t, cnt, figsize=figsize)

# %%
from rasterio.plot import show_hist
from matplotlib import pyplot
# %matplotlib inline
#from utils.utils import threeBandImage
#from utils.utils import loadConfigExtent
def plot_me(ds, time, count):
    figsize = [8,8]
    
    # img_toshow = threeBandImage(ds,bands = ['red', 'green', 'blue'], time = time)
    # img_toshow = nb_rgb(ds,bands = ['red', 'green', 'blue'], index = count, index_dim='datePR')

    nb_rgb(ds,bands = ['red', 'green', 'blue'], index = count, index_dim='datePR')

    fig = pyplot.figure(figsize = figsize)
    #pyplot.imshow(img_toshow)
    img_toshow.plot.imshow()
    ax = pyplot.gca()
    # title_string = "IMG " + str(count)
    title_string = ""
    figName = title_string + '.png'
    title_string = title_string + " --> " + str(ds.time[time].values).split('T')[0]
    time_string = str(ds.time[time].values).split('T')[0]
    time_string = str(ds.datePR[time].values)
    figName = time_string + '.png'
    ax.set_title(title_string, fontweight = 'bold', fontsize = 16)
    ax.set_xticklabels(ds.x.values)
    ax.set_yticklabels(ds.y.values)
    ax.set_xlabel('Easting', fontweight = 'bold')
    ax.set_ylabel('Northing', fontweight = 'bold')
    pyplot.savefig(figName)
    # if you remove the close below the images will display - uses lots of memory though
    pyplot.close(fig)
    return True

# %%
"""
ntime = len(ds2.datePR)
cnt = 0
for t in range (ntime):
    print("Hi",cnt)
    cnt = cnt + 1
    plot_me(ds2, t, cnt)
    
    """

# %%
# !ls

# %%
! convert -delay 100 *.png -loop 10 l7_movie.gif
#! scp movie.gif sleepy:.

! rm *.png

# %%
# !date

# %% [markdown]
# ![run movie](./l7_movie.gif)

# %%
# !ls

# %% [markdown]
# ```bash
# tony@odc:/opt/little-cloud/lib/lilcubeLib/lilcubeLib$ cloc .
#        5 text files.
#        5 unique files.
#        0 files ignored.
#
# http://cloc.sourceforge.net v 1.60  T=0.16 s (32.2 files/s, 8011.0 lines/s)
# -------------------------------------------------------------------------------
# Language                     files          blank        comment           code
# -------------------------------------------------------------------------------
# Python                           5            304            300            639
# -------------------------------------------------------------------------------
# SUM:                             5            304            300            639
# -------------------------------------------------------------------------------
# tony@odc:/opt/little-cloud/lib/lilcubeLib/lilcubeLib$ wc *.py
#   867  2386 26127 geometry.py
#    71   185  2037 lc_api.py
#    64   128  1501 lc_elastic.py
#    50   108   825 lc_geometry.py
#   191   488  5565 lc_xarray.py
#  1243  3295 36055 total
# tony@odc:/opt/little-cloud/lib/lilcubeLib/lilcubeLib$
# ```

# %% [markdown]
# ```bash
# tony@odc:/opt/build/datacube-core-datacube-1.6rc1$ cloc .
#      346 text files.
#      341 unique files.
#      118 files ignored.
#
# http://cloc.sourceforge.net v 1.60  T=5.40 s (43.7 files/s, 8457.2 lines/s)
# -------------------------------------------------------------------------------
# Language                     files          blank        comment           code
# -------------------------------------------------------------------------------
# Python                         158           6649           6767          20085
# YAML                            62            633            124          10028
# XML                              3              2              0            704
# SQL                              3             24              4            203
# Bourne Shell                     7             52             24            173
# make                             1             29              6            145
# DOS Batch                        1              9              1             32
# HTML                             1              1              0              6
# -------------------------------------------------------------------------------
# SUM:                           236           7399           6926          31376
# -------------------------------------------------------------------------------
# tony@odc:/opt/build/datacube-core-datacube-1.6rc1$
# ```

# %%
import pandas
code = {
    'odc-lite': 639,
    'datacube-core': 31376
}

df = pandas.DataFrame(code, index=[0])

# %%
df

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar')

# %%
from IPython.display import Image
Image(filename=('l7_movie.gif'))

# %%
from notebookLib.nb_DEAPlotting import animated_timeseries
animated_timeseries(ds2,output_path='./abc2.mp4',bands = ['red', 'green', 'blue'], time_dim='datePR',  
       percentile_stretch=(.2,.85), interval=1200)

# %%
# !ls

# %%
# !ls -l abc.mp4

# %%
# help(animated_timeseries)

# %%
from notebookLib.nb_animate import nb_animated_timeseries
nb_animated_timeseries(ds2,output_path='./abc3.mp4',bands = ['red', 'green', 'blue'], time_dim='datePR',  
       percentile_stretch=(.2,.85), interval=1200)

# %% [markdown]
# ## Last modified: November 2018
# ## Authors: Claire Krause, Robbi Bishop-Taylor, Sean Chua, Mike Barnes, Cate Kooymans, Bex Dunn
