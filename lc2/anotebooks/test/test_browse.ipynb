# %%
# test browse

# %%
from noteLib import *
from dcindexLib.dc_dataset import get_rgb_filenames

import datacube

# %%
from datetime import datetime
date_range = (
        datetime(2013,4,10),
        datetime(2013,4,11))

# %%
import datacube
dc= datacube.Datacube()

# from bounding box
# https://boundingbox.klokantech.com/
extent = (30.209661,-2.218817,30.246396,-2.163926)

x = (extent[0],extent[2])
y = (extent[1],extent[3])

print (x,y)

aoix = x
aoiy = y
# Out:
# (30.209661, 30.246396) (-2.218817, -2.163926)

# %%
product = 'l8_rwanda'
dsets = dc.find_datasets(product=product,x = x, y = y,
             output_crs = 'epsg:32636', resolution = (-30,30), 
             time = date_range, measurements = ('red', 'green', 'blue','nir') )

# %%
myds = dsets[0]
rgb = []
rgb = get_rgb_filenames(myds)

# %%
# rgb = ['a','b','c']
out = 'dummy.png'

build_browse(rgb, out)
# Out:
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band4.tif
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band4_wrk.tif
# [ STATS ] =  Minimum=-45.000, Maximum=11417.000, Mean=1182.385, StdDev=1484.158
# hello THERE
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band3.tif
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band3_wrk.tif
# [ STATS ] =  Minimum=11.000, Maximum=11106.000, Mean=1255.583, StdDev=1433.929
# hello THERE
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2.tif
# /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrk.tif
# ...

# %%
! ls -l /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/*wrk*
# Out:
# -rw-rw-r-- 1 tony tony 553 Dec 31 16:19 /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrk.tif.aux.xml
# -rw-rw-r-- 1 tony tony 552 Dec 31 16:19 /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band3_wrk.tif.aux.xml
# -rw-rw-r-- 1 tony tony 552 Dec 31 16:19 /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band4_wrk.tif.aux.xml

# %%
! scp /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/*wrk* sleepy:/data/tmp
# Out:
# LC08_L1TP_172062_20130410_20170505_01_T1_sr_b 100%  553     0.5KB/s   00:00
# LC08_L1TP_172062_20130410_20170505_01_T1_sr_b 100%  552     0.5KB/s   00:00
# LC08_L1TP_172062_20130410_20170505_01_T1_sr_b 100%  552     0.5KB/s   00:00

# %%
! ls -l /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/
# Out:
# total 919788
# -rw-r--r-- 1 tony tony    117139 May  5  2017 LC08_L1TP_172062_20130410_20170505_01_T1_ANG.txt
# -rw-rw-r-- 1 tony tony   2302981 Dec 31 16:19 LC08_L1TP_172062_20130410_20170505_01_T1_browse.png
# -rw-r--r-- 1 tony tony 109146895 Nov 29 21:14 LC08_L1TP_172062_20130410_20170505_01_T1_bt_band10.tif
# -rw-r--r-- 1 tony tony 109146895 Nov 29 21:14 LC08_L1TP_172062_20130410_20170505_01_T1_bt_band11.tif
# -rw-r--r-- 1 tony tony      8695 Nov 29 21:12 LC08_L1TP_172062_20130410_20170505_01_T1_MTL.txt
# -rw-r--r-- 1 tony tony 109146845 Nov 29 21:14 LC08_L1TP_172062_20130410_20170505_01_T1_pixel_qa.tif
# -rw-r--r-- 1 tony tony 109146823 Nov 29 21:14 LC08_L1TP_172062_20130410_20170505_01_T1_radsat_qa.tif
# -rw-r--r-- 1 tony tony  54602886 Nov 29 21:14 LC08_L1TP_172062_20130410_20170505_01_T1_sr_aerosol.tif
# -rw-rw-r-- 1 tony tony  60508728 Dec 28 22:36 LC08_L1TP_172062_20130410_20170505_01_T1_sr_band1.tif
# ...

# %%
# !ls
# ! rm /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/*aux*
# Out:
# dummy.png  test_browse.ipynb

# %%
# ! display dummy.png

# %%
from IPython.display import Image
Image(filename='dummy.png')

# %%
# !gdalinfo dummy.png
# Out:
# Driver: PNG/Portable Network Graphics
# Files: dummy.png
# Size is 747, 732
# Coordinate System is `'
# Image Structure Metadata:
#   INTERLEAVE=PIXEL
# Corner Coordinates:
# Upper Left  (    0.0,    0.0)
# Lower Left  (    0.0,  732.0)
# Upper Right (  747.0,    0.0)
# Lower Right (  747.0,  732.0)
# Center      (  373.5,  366.0)
# Band 1 Block=747x1 Type=UInt16, ColorInterp=Red
#   Mask Flags: PER_DATASET ALPHA
# Band 2 Block=747x1 Type=UInt16, ColorInterp=Green
#   Mask Flags: PER_DATASET ALPHA
# Band 3 Block=747x1 Type=UInt16, ColorInterp=Blue
#   Mask Flags: PER_DATASET ALPHA
# Band 4 Block=747x1 Type=UInt16, ColorInterp=Alpha

# %%
# !gdalinfo /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkrgb.tif
# Out:
# ERROR 4: /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkrgb.tif: No such file or directory
# gdalinfo failed - unable to open '/mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkrgb.tif'.

# %%
# !gdalinfo /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkprgb.tif
# Out:
# ERROR 4: /mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkprgb.tif: No such file or directory
# gdalinfo failed - unable to open '/mnt/rwanda/LC08/172/062/2013/LC081720622013041001T1-SC20181129211422/LC08_L1TP_172062_20130410_20170505_01_T1_sr_band2_wrkprgb.tif'.
