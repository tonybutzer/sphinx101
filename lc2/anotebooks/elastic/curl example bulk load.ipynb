# %% [markdown]
# # Load Music
#
# ## I used music - since its data and metadata I am familiar with
#
# ## Plex
#
# ### Could then develop play lists - such as play all the songs that have the word 'wild' in them.
#
# - use curl to bulk load a music index of type song with _ids

# %%
! head a.json
# Out:
# { "index" : { "_index" : "music", "_type" : "song", "_id" : "1" } }
# {"year": "1981\u0000", "artist": "William Ackerman\u0000", "publisher": "Windham Hill Records\u0000", "composer": "Will Ackerman\u0000", "band": "William Ackerman\u0000", "path": "/mnt/nuc/music-best/beets/EasyListening/William Ackerman/Passage/08 Passage.mp3", "genre": "New Age\u0000", "track": "8/8\u0000", "album": "Passage\u0000", "song": "Passage"}
# { "index" : { "_index" : "music", "_type" : "song", "_id" : "2" } }
# {"year": "1981\u0000", "artist": "William Ackerman\u0000", "publisher": "Windham Hill Records\u0000", "composer": "Will Ackerman\u0000", "band": "William Ackerman\u0000", "path": "/mnt/nuc/music-best/beets/EasyListening/William Ackerman/Passage/03 The Impending Death of the Virgin Spirit.mp3", "genre": "New Age\u0000", "track": "3/8\u0000", "album": "Passage\u0000", "song": "The Impending Death of the Vir"}
# { "index" : { "_index" : "music", "_type" : "song", "_id" : "3" } }
# ...

# %%
! curl -s -H "Content-Type: application/x-ndjson" -XPOST elastic:9200/_bulk --data-binary @a.json
# Out:
# {"took":560,"errors":false,"items":[{"index":{"_index":"music","_type":"song","_id":"1","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1,"status":201}},{"index":{"_index":"music","_type":"song","_id":"2","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1,"status":201}},{"index":{"_index":"music","_type":"song","_id":"3","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1,"status":201}},{"index":{"_index":"music","_type":"song","_id":"4","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":1,"_primary_term":1,"status":201}},{"index":{"_index":"music","_type":"song","_id":"5","_version":1,"result":"created","_shards":{"total":2,"successful":1,"failed":0},"_seq_no":0,"_primary_term":1,"status":201}},{"index":{"_index":"music","_type":"song","_id":"6","_version":1,"result":"cr
# ...

# %%
# ! curl -s -H "Content-Type: application/x-ndjson" -XPOST elastic:9200/_bulk --data-binary @music_bulk.json
